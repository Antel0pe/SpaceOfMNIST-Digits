# %%
import torch
from torch.utils.data import Subset
import torchvision
from torchvision import transforms
import matplotlib.pyplot as plt

# %%
# Define the transformation pipeline:
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Lambda(lambda x: (x > 0.5).float()),  # Binarize the image
    transforms.Lambda(lambda x: x.view(-1))           # Flatten into a 784-dim vector
])

# Load the training set (set download=True if running for the first time)
mnist_train = torchvision.datasets.MNIST(root='./data', train=True, download=True, transform=transform)
# Out:
# 100%|██████████| 9.91M/9.91M [00:00<00:00, 20.4MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 609kB/s]
# 100%|██████████| 1.65M/1.65M [00:00<00:00, 5.62MB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 6.68MB/s]

# %%
# Get indices for images where the label is 1
indices = (mnist_train.targets == 1).nonzero().squeeze()

# Create a subset containing only the '1's
mnist_train_ones = Subset(mnist_train, indices)

print(f"Total number of '1' images in the training set: {len(mnist_train_ones)}")
# Out:
# Total number of '1' images in the training set: 6742

# %%
# Retrieve one sample from the filtered dataset
sample_img, sample_label = mnist_train_ones[0]

print("Shape of the flattened image:", sample_img.shape)  # Should be [784]

# Reshape back to 28x28 for visualization
img_reshaped = sample_img.view(28, 28)

plt.imshow(img_reshaped, cmap='gray')
plt.title(f"Label: {sample_label}")
plt.axis('off')
plt.show()
# Out:
# Shape of the flattened image: torch.Size([784])

# %%
import random
import matplotlib.pyplot as plt

# Randomly sample two images from the filtered dataset of 1s
idx1 = random.randint(0, len(mnist_train_ones) - 1)
idx2 = random.randint(0, len(mnist_train_ones) - 1)
img1, label1 = mnist_train_ones[idx1]
img2, label2 = mnist_train_ones[idx2]

# Define interpolation factors including the originals (0% and 100%)
factors = [0.0, 0.25, 0.5, 0.75, 1.0]

# Precompute raw interpolations (they are still 784-dim vectors)
raw_interpolations = [(1 - t) * img1 + t * img2 for t in factors]

# Row 1: Original interpolated images (continuous values)
row1 = [ri.view(28, 28) for ri in raw_interpolations]

# Row 2: Only include pixels that are 1 in both original images.
# Compute a mask that is 1 only where both img1 and img2 have a 1.
mask = ((img1 == 1) & (img2 == 1)).float()
row2 = [(ri * mask).view(28, 28) for ri in raw_interpolations]

# Row 3: Threshold all nonzero pixels to 1.
row3 = [ (ri > 0).float().view(28, 28) for ri in raw_interpolations]

# Plot all rows in a 3 x 5 grid.
fig, axs = plt.subplots(3, 5, figsize=(16, 9))
titles = ["0% (img1)", "25%", "50%", "75%", "100% (img2)"]

# Set column titles for the top row
for j, title in enumerate(titles):
    axs[0, j].set_title(title)

# Define row labels
row_labels = ["Original Interpolation", "Intersection Mask Applied", "Binary Threshold"]

# Plot each row.
for i, row in enumerate([row1, row2, row3]):
    # Add a label to the first column of each row
    axs[i, 0].set_ylabel(row_labels[i], fontsize=12, labelpad=10)
    for j, img in enumerate(row):
        axs[i, j].imshow(img, cmap='gray')
        # axs[i, j].axis('off')

# Adjust subplot parameters to provide more space on the left
plt.subplots_adjust(left=0.15)

plt.tight_layout()
plt.show()

# %%
import random
import torch
import matplotlib.pyplot as plt

# Randomly choose a first image from the dataset of 1s
idx1 = random.randint(0, len(mnist_train_ones) - 1)
img1, label1 = mnist_train_ones[idx1]

# Find the closest image to img1 using Euclidean L2 distance
min_distance = float('inf')
closest_img = None
closest_idx = None

for i in range(len(mnist_train_ones)):
    if i == idx1:  # Skip the same image
        continue
    candidate, _ = mnist_train_ones[i]
    # Compute the L2 (Euclidean) distance between img1 and candidate
    distance = torch.dist(img1, candidate, p=2)
    if distance < min_distance:
        min_distance = distance
        closest_img = candidate
        closest_idx = i

print("Minimum Euclidean distance:", min_distance)

# Define interpolation factors (0% and 100% correspond to img1 and closest_img)
factors = [0.0, 0.25, 0.5, 0.75, 1.0]
interpolated_images = []
for t in factors:
    interp_img = (1 - t) * img1 + t * closest_img  # Linear interpolation
    interpolated_images.append(interp_img.view(28, 28))  # Reshape to 28x28 for plotting

# Plot the original images and interpolated results
fig, axs = plt.subplots(1, len(interpolated_images), figsize=(15, 3))
titles = ["0% (img1)", "25%", "50%", "75%", "100% (closest)"]

for ax, img, title in zip(axs, interpolated_images, titles):
    ax.imshow(img, cmap='gray')
    ax.set_title(title)
    ax.axis('off')

plt.tight_layout()
plt.show()
# Out:
# Minimum Euclidean distance: tensor(2.)

# %%
# Stack all 784-dim vectors from the filtered dataset
all_vectors = torch.stack([img for img, _ in mnist_train_ones])
unique_vectors = torch.unique(all_vectors, dim=0)

print(f"Total images in mnist_train_ones: {all_vectors.shape[0]}")
print(f"Unique images: {unique_vectors.shape[0]}")

if all_vectors.shape[0] == unique_vectors.shape[0]:
    print("All 784-dimensional vectors are unique.")
else:
    print("There are duplicates in the 784-dimensional vectors.")
# Out:
# Total images in mnist_train_ones: 6742
# Unique images: 6726
# There are duplicates in the 784-dimensional vectors.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.cluster import DBSCAN

def visualize_clusters(unique_vectors, method='tsne', clustering_eps=5.5, clustering_min_samples=5):
    """
    Visualizes clusters among unique_vectors by reducing dimensions to 2D and running DBSCAN.

    Args:
        unique_vectors (torch.Tensor or np.array): Array of shape (n, 784) containing unique images.
        method (str): 'tsne' (default) or 'pca' for dimensionality reduction.
        clustering_eps (float): The DBSCAN eps parameter.
        clustering_min_samples (int): The DBSCAN min_samples parameter.
    """
    # Convert tensor to numpy array if necessary.
    if hasattr(unique_vectors, 'cpu'):
        X = unique_vectors.cpu().numpy()
    else:
        X = unique_vectors

    # Dimensionality Reduction to 2D.
    if method.lower() == 'pca':
        reducer = PCA(n_components=2)
    else:
        reducer = TSNE(n_components=2, perplexity=30, random_state=42)
    X_reduced = reducer.fit_transform(X)

    # Cluster using DBSCAN.
    clustering = DBSCAN(eps=clustering_eps, min_samples=clustering_min_samples)
    labels = clustering.fit_predict(X_reduced)

    # Number of clusters (excluding noise label -1).
    n_clusters = len(set(labels)) - (1 if -1 in labels else 0)
    print(f"Estimated number of clusters (excluding noise): {n_clusters}")

    # Visualize clusters.
    plt.figure(figsize=(10, 8))
    unique_labels = np.unique(labels)
    for label in unique_labels:
        # Set label name; noise is labeled as -1.
        label_name = f'Cluster {label}' if label != -1 else 'Noise'
        idx = labels == label
        plt.scatter(X_reduced[idx, 0], X_reduced[idx, 1], label=label_name, s=10)
    plt.title(f'2D Visualization of Unique Vectors using {method.upper()} with DBSCAN')
    plt.xlabel('Component 1')
    plt.ylabel('Component 2')
    plt.legend()
    plt.show()

visualize_clusters(unique_vectors, method='tsne', clustering_eps=4, clustering_min_samples=1)
# Out:
# Estimated number of clusters (excluding noise): 5

# %%
import random
import torch

def ball_cluster(unique_vectors, distance_threshold):
    """
    Clusters the unique 784-d vectors by repeatedly choosing a random center
    and grouping all vectors within the given Euclidean distance.

    Args:
      unique_vectors (torch.Tensor): Tensor of shape (n, 784) with unique images.
      distance_threshold (float): Maximum Euclidean distance for including a vector in a cluster.

    Returns:
      cluster_strings (list of str): List of strings describing each cluster, e.g. "Cluster 0: 12 nodes".
      clusters (list of lists): Each sublist contains the indices of unique_vectors belonging to that cluster.
    """
    clusters = []  # List to hold clusters (each cluster is a list of indices)
    remaining = set(range(unique_vectors.shape[0]))  # All indices that haven't been assigned yet

    while remaining:
        # Randomly choose a center from the remaining indices
        center_idx = random.choice(list(remaining))
        center = unique_vectors[center_idx]

        # Get a list of remaining indices and corresponding candidate vectors
        remaining_list = list(remaining)
        candidates = unique_vectors[remaining_list]  # shape: [num_remaining, 784]

        # Compute Euclidean distances between center and each candidate
        distances = torch.norm(candidates - center, dim=1)

        # Find indices where distance is within threshold
        within_threshold = [remaining_list[i] for i, d in enumerate(distances) if d <= distance_threshold]

        # Add this set as a new cluster
        clusters.append(within_threshold)

        # Remove these indices from the remaining set
        remaining = remaining.difference(within_threshold)

    # Create a string list summarizing each cluster
    for i, cluster in enumerate(clusters):
        print(f"Cluster {i}: {len(cluster)} nodes")

    return clusters

clusters = ball_cluster(unique_vectors, 4)
# Out:
# Cluster 0: 96 nodes
# Cluster 1: 95 nodes
# Cluster 2: 84 nodes
# Cluster 3: 130 nodes
# Cluster 4: 175 nodes
# Cluster 5: 99 nodes
# Cluster 6: 132 nodes
# Cluster 7: 42 nodes
# Cluster 8: 213 nodes
# Cluster 9: 82 nodes
# Cluster 10: 74 nodes
# Cluster 11: 59 nodes
# Cluster 12: 54 nodes
# Cluster 13: 23 nodes
# Cluster 14: 143 nodes
# Cluster 15: 23 nodes
# Cluster 16: 90 nodes
# Cluster 17: 9 nodes
# Cluster 18: 4 nodes
# Cluster 19: 62 nodes
# Cluster 20: 31 nodes
# Cluster 21: 122 nodes
# Cluster 22: 137 nodes
# Cluster 23: 45 nodes
# Cluster 24: 46 nodes
# Cluster 25: 4 nodes
# Cluster 26: 167 nodes
# Cluster 27: 33 nodes
# Cluster 28: 115 nodes
# Cluster 29: 44 nodes
# Cluster 30: 2 nodes
# Cluster 31: 14 nodes
# Cluster 32: 53 nodes
# Cluster 33: 1 nodes
# Cluster 34: 1 nodes
# Cluster 35: 157 nodes
# Cluster 36: 7 nodes
# Cluster 37: 42 nodes
# Cluster 38: 57 nodes
# Cluster 39: 7 nodes
# Cluster 40: 27 nodes
# Cluster 41: 39 nodes
# Cluster 42: 11 nodes
# Cluster 43: 6 nodes
# Cluster 44: 8 nodes
# Cluster 45: 1 nodes
# Cluster 46: 23 nodes
# Cluster 47: 33 nodes
# Cluster 48: 14 nodes
# Cluster 49: 8 nodes
# Cluster 50: 13 nodes
# Cluster 51: 116 nodes
# Cluster 52: 12 nodes
# Cluster 53: 1 nodes
# Cluster 54: 5 nodes
# Cluster 55: 76 nodes
# Cluster 56: 60 nodes
# Cluster 57: 4 nodes
# Cluster 58: 5 nodes
# Cluster 59: 21 nodes
# Cluster 60: 21 nodes
# Cluster 61: 40 nodes
# Cluster 62: 15 nodes
# Cluster 63: 10 nodes
# Cluster 64: 1 nodes
# Cluster 65: 7 nodes
# Cluster 66: 15 nodes
# Cluster 67: 19 nodes
# Cluster 68: 3 nodes
# Cluster 69: 1 nodes
# Cluster 70: 2 nodes
# Cluster 71: 11 nodes
# Cluster 72: 2 nodes
# Cluster 73: 28 nodes
# Cluster 74: 33 nodes
# Cluster 75: 14 nodes
# Cluster 76: 1 nodes
# Cluster 77: 1 nodes
# Cluster 78: 32 nodes
# Cluster 79: 1 nodes
# Cluster 80: 4 nodes
# Cluster 81: 15 nodes
# Cluster 82: 1 nodes
# Cluster 83: 12 nodes
# Cluster 84: 1 nodes
# Cluster 85: 12 nodes
# Cluster 86: 13 nodes
# Cluster 87: 41 nodes
# Cluster 88: 1 nodes
# Cluster 89: 29 nodes
# Cluster 90: 24 nodes
# Cluster 91: 37 nodes
# Cluster 92: 1 nodes
# Cluster 93: 24 nodes
# Cluster 94: 3 nodes
# Cluster 95: 2 nodes
# Cluster 96: 15 nodes
# Cluster 97: 3 nodes
# Cluster 98: 20 nodes
# Cluster 99: 2 nodes
# Cluster 100: 22 nodes
# Cluster 101: 25 nodes
# Cluster 102: 8 nodes
# Cluster 103: 6 nodes
# Cluster 104: 2 nodes
# Cluster 105: 1 nodes
# Cluster 106: 12 nodes
# Cluster 107: 1 nodes
# Cluster 108: 4 nodes
# Cluster 109: 1 nodes
# Cluster 110: 6 nodes
# Cluster 111: 57 nodes
# Cluster 112: 8 nodes
# Cluster 113: 1 nodes
# Cluster 114: 11 nodes
# Cluster 115: 1 nodes
# Cluster 116: 6 nodes
# Cluster 117: 4 nodes
# Cluster 118: 10 nodes
# Cluster 119: 9 nodes
# Cluster 120: 1 nodes
# Cluster 121: 1 nodes
# Cluster 122: 60 nodes
# Cluster 123: 7 nodes
# Cluster 124: 5 nodes
# Cluster 125: 5 nodes
# Cluster 126: 1 nodes
# Cluster 127: 2 nodes
# Cluster 128: 1 nodes
# Cluster 129: 3 nodes
# Cluster 130: 4 nodes
# Cluster 131: 10 nodes
# Cluster 132: 8 nodes
# Cluster 133: 1 nodes
# Cluster 134: 1 nodes
# Cluster 135: 3 nodes
# Cluster 136: 5 nodes
# Cluster 137: 6 nodes
# Cluster 138: 3 nodes
# Cluster 139: 6 nodes
# Cluster 140: 11 nodes
# Cluster 141: 2 nodes
# Cluster 142: 7 nodes
# Cluster 143: 1 nodes
# Cluster 144: 1 nodes
# Cluster 145: 20 nodes
# Cluster 146: 6 nodes
# Cluster 147: 6 nodes
# Cluster 148: 9 nodes
# Cluster 149: 12 nodes
# Cluster 150: 35 nodes
# Cluster 151: 7 nodes
# Cluster 152: 13 nodes
# Cluster 153: 4 nodes
# Cluster 154: 4 nodes
# Cluster 155: 5 nodes
# Cluster 156: 1 nodes
# Cluster 157: 8 nodes
# Cluster 158: 9 nodes
# Cluster 159: 9 nodes
# Cluster 160: 3 nodes
# Cluster 161: 6 nodes
# Cluster 162: 1 nodes
# Cluster 163: 7 nodes
# Cluster 164: 8 nodes
# Cluster 165: 1 nodes
# Cluster 166: 10 nodes
# Cluster 167: 3 nodes
# Cluster 168: 9 nodes
# Cluster 169: 1 nodes
# Cluster 170: 14 nodes
# Cluster 171: 1 nodes
# Cluster 172: 3 nodes
# Cluster 173: 11 nodes
# Cluster 174: 1 nodes
# Cluster 175: 18 nodes
# Cluster 176: 1 nodes
# Cluster 177: 4 nodes
# Cluster 178: 7 nodes
# Cluster 179: 52 nodes
# Cluster 180: 1 nodes
# Cluster 181: 1 nodes
# Cluster 182: 7 nodes
# Cluster 183: 10 nodes
# Cluster 184: 2 nodes
# Cluster 185: 36 nodes
# Cluster 186: 5 nodes
# Cluster 187: 8 nodes
# Cluster 188: 25 nodes
# Cluster 189: 9 nodes
# Cluster 190: 9 nodes
# Cluster 191: 18 nodes
# Cluster 192: 8 nodes
# Cluster 193: 1 nodes
# Cluster 194: 25 nodes
# Cluster 195: 3 nodes
# Cluster 196: 4 nodes
# Cluster 197: 2 nodes
# Cluster 198: 10 nodes
# Cluster 199: 6 nodes
# Cluster 200: 6 nodes
# Cluster 201: 32 nodes
# Cluster 202: 2 nodes
# Cluster 203: 38 nodes
# Cluster 204: 9 nodes
# Cluster 205: 10 nodes
# Cluster 206: 8 nodes
# Cluster 207: 1 nodes
# Cluster 208: 2 nodes
# Cluster 209: 1 nodes
# Cluster 210: 2 nodes
# Cluster 211: 6 nodes
# Cluster 212: 1 nodes
# Cluster 213: 6 nodes
# Cluster 214: 22 nodes
# Cluster 215: 1 nodes
# Cluster 216: 7 nodes
# Cluster 217: 1 nodes
# Cluster 218: 13 nodes
# Cluster 219: 1 nodes
# Cluster 220: 2 nodes
# Cluster 221: 14 nodes
# Cluster 222: 2 nodes
# Cluster 223: 1 nodes
# Cluster 224: 2 nodes
# Cluster 225: 8 nodes
# Cluster 226: 3 nodes
# Cluster 227: 2 nodes
# Cluster 228: 6 nodes
# Cluster 229: 11 nodes
# Cluster 230: 2 nodes
# Cluster 231: 3 nodes
# Cluster 232: 4 nodes
# Cluster 233: 4 nodes
# Cluster 234: 8 nodes
# Cluster 235: 2 nodes
# Cluster 236: 1 nodes
# Cluster 237: 23 nodes
# Cluster 238: 1 nodes
# Cluster 239: 1 nodes
# Cluster 240: 6 nodes
# Cluster 241: 5 nodes
# Cluster 242: 3 nodes
# Cluster 243: 2 nodes
# Cluster 244: 1 nodes
# Cluster 245: 5 nodes
# Cluster 246: 2 nodes
# Cluster 247: 1 nodes
# Cluster 248: 23 nodes
# Cluster 249: 1 nodes
# Cluster 250: 3 nodes
# Cluster 251: 4 nodes
# Cluster 252: 12 nodes
# Cluster 253: 6 nodes
# Cluster 254: 25 nodes
# Cluster 255: 11 nodes
# Cluster 256: 8 nodes
# Cluster 257: 8 nodes
# Cluster 258: 1 nodes
# Cluster 259: 1 nodes
# Cluster 260: 6 nodes
# Cluster 261: 6 nodes
# Cluster 262: 1 nodes
# Cluster 263: 1 nodes
# Cluster 264: 16 nodes
# Cluster 265: 3 nodes
# Cluster 266: 1 nodes
# Cluster 267: 1 nodes
# Cluster 268: 3 nodes
# Cluster 269: 1 nodes
# Cluster 270: 1 nodes
# Cluster 271: 9 nodes
# Cluster 272: 5 nodes
# Cluster 273: 8 nodes
# Cluster 274: 2 nodes
# Cluster 275: 1 nodes
# Cluster 276: 1 nodes
# Cluster 277: 1 nodes
# Cluster 278: 1 nodes
# Cluster 279: 4 nodes
# Cluster 280: 2 nodes
# Cluster 281: 1 nodes
# Cluster 282: 3 nodes
# Cluster 283: 1 nodes
# Cluster 284: 1 nodes
# Cluster 285: 7 nodes
# Cluster 286: 2 nodes
# Cluster 287: 1 nodes
# Cluster 288: 2 nodes
# Cluster 289: 11 nodes
# Cluster 290: 5 nodes
# Cluster 291: 7 nodes
# Cluster 292: 1 nodes
# Cluster 293: 5 nodes
# Cluster 294: 2 nodes
# Cluster 295: 2 nodes
# Cluster 296: 2 nodes
# Cluster 297: 1 nodes
# Cluster 298: 2 nodes
# Cluster 299: 1 nodes
# Cluster 300: 3 nodes
# Cluster 301: 3 nodes
# Cluster 302: 1 nodes
# Cluster 303: 11 nodes
# Cluster 304: 5 nodes
# Cluster 305: 4 nodes
# Cluster 306: 1 nodes
# Cluster 307: 4 nodes
# Cluster 308: 4 nodes
# Cluster 309: 3 nodes
# Cluster 310: 1 nodes
# Cluster 311: 1 nodes
# Cluster 312: 1 nodes
# Cluster 313: 1 nodes
# Cluster 314: 2 nodes
# Cluster 315: 1 nodes
# Cluster 316: 1 nodes
# Cluster 317: 1 nodes
# Cluster 318: 6 nodes
# Cluster 319: 1 nodes
# Cluster 320: 7 nodes
# Cluster 321: 2 nodes
# Cluster 322: 3 nodes
# Cluster 323: 6 nodes
# Cluster 324: 3 nodes
# Cluster 325: 1 nodes
# Cluster 326: 1 nodes
# Cluster 327: 15 nodes
# Cluster 328: 1 nodes
# Cluster 329: 2 nodes
# Cluster 330: 1 nodes
# Cluster 331: 1 nodes
# Cluster 332: 1 nodes
# Cluster 333: 1 nodes
# Cluster 334: 10 nodes
# Cluster 335: 1 nodes
# Cluster 336: 3 nodes
# Cluster 337: 1 nodes
# Cluster 338: 1 nodes
# Cluster 339: 1 nodes
# Cluster 340: 1 nodes
# Cluster 341: 1 nodes
# Cluster 342: 1 nodes
# Cluster 343: 4 nodes
# Cluster 344: 3 nodes
# Cluster 345: 3 nodes
# Cluster 346: 3 nodes
# Cluster 347: 2 nodes
# Cluster 348: 1 nodes
# Cluster 349: 9 nodes
# Cluster 350: 3 nodes
# Cluster 351: 7 nodes
# Cluster 352: 1 nodes
# Cluster 353: 4 nodes
# Cluster 354: 5 nodes
# Cluster 355: 1 nodes
# Cluster 356: 6 nodes
# Cluster 357: 1 nodes
# Cluster 358: 3 nodes
# Cluster 359: 3 nodes
# Cluster 360: 7 nodes
# Cluster 361: 13 nodes
# Cluster 362: 1 nodes
# Cluster 363: 4 nodes
# Cluster 364: 1 nodes
# Cluster 365: 13 nodes
# Cluster 366: 1 nodes
# Cluster 367: 1 nodes
# Cluster 368: 4 nodes
# Cluster 369: 5 nodes
# Cluster 370: 1 nodes
# Cluster 371: 1 nodes
# Cluster 372: 5 nodes
# Cluster 373: 1 nodes
# Cluster 374: 5 nodes
# Cluster 375: 1 nodes
# Cluster 376: 2 nodes
# Cluster 377: 1 nodes
# Cluster 378: 4 nodes
# Cluster 379: 3 nodes
# Cluster 380: 4 nodes
# Cluster 381: 3 nodes
# Cluster 382: 4 nodes
# Cluster 383: 1 nodes
# Cluster 384: 7 nodes
# Cluster 385: 1 nodes
# Cluster 386: 2 nodes
# Cluster 387: 1 nodes
# Cluster 388: 1 nodes
# Cluster 389: 1 nodes
# Cluster 390: 1 nodes
# Cluster 391: 1 nodes
# Cluster 392: 4 nodes
# Cluster 393: 3 nodes
# Cluster 394: 1 nodes
# Cluster 395: 7 nodes
# Cluster 396: 6 nodes
# Cluster 397: 1 nodes
# Cluster 398: 4 nodes
# Cluster 399: 1 nodes
# Cluster 400: 1 nodes
# Cluster 401: 1 nodes
# Cluster 402: 1 nodes
# Cluster 403: 1 nodes
# Cluster 404: 2 nodes
# Cluster 405: 2 nodes
# Cluster 406: 3 nodes
# Cluster 407: 2 nodes
# Cluster 408: 5 nodes
# Cluster 409: 1 nodes
# Cluster 410: 4 nodes
# Cluster 411: 1 nodes
# Cluster 412: 2 nodes
# Cluster 413: 1 nodes
# Cluster 414: 1 nodes
# Cluster 415: 1 nodes
# Cluster 416: 1 nodes
# Cluster 417: 2 nodes
# Cluster 418: 10 nodes
# Cluster 419: 1 nodes
# Cluster 420: 4 nodes
# Cluster 421: 1 nodes
# Cluster 422: 1 nodes
# Cluster 423: 1 nodes
# Cluster 424: 3 nodes
# Cluster 425: 5 nodes
# Cluster 426: 2 nodes
# Cluster 427: 1 nodes
# Cluster 428: 1 nodes
# Cluster 429: 1 nodes
# Cluster 430: 2 nodes
# Cluster 431: 6 nodes
# Cluster 432: 1 nodes
# Cluster 433: 2 nodes
# Cluster 434: 4 nodes
# Cluster 435: 1 nodes
# Cluster 436: 1 nodes
# Cluster 437: 4 nodes
# Cluster 438: 8 nodes
# Cluster 439: 2 nodes
# Cluster 440: 1 nodes
# Cluster 441: 2 nodes
# Cluster 442: 2 nodes
# Cluster 443: 7 nodes
# Cluster 444: 1 nodes
# Cluster 445: 1 nodes
# Cluster 446: 1 nodes
# Cluster 447: 1 nodes
# Cluster 448: 4 nodes
# Cluster 449: 1 nodes
# Cluster 450: 3 nodes
# Cluster 451: 1 nodes
# Cluster 452: 1 nodes
# Cluster 453: 1 nodes
# Cluster 454: 1 nodes
# Cluster 455: 1 nodes
# Cluster 456: 1 nodes
# Cluster 457: 1 nodes
# Cluster 458: 1 nodes
# Cluster 459: 4 nodes
# Cluster 460: 1 nodes
# Cluster 461: 3 nodes
# Cluster 462: 1 nodes
# Cluster 463: 1 nodes
# Cluster 464: 4 nodes
# Cluster 465: 1 nodes
# Cluster 466: 3 nodes
# Cluster 467: 1 nodes
# Cluster 468: 8 nodes
# Cluster 469: 1 nodes
# Cluster 470: 1 nodes
# Cluster 471: 2 nodes
# Cluster 472: 2 nodes
# Cluster 473: 2 nodes
# Cluster 474: 6 nodes
# Cluster 475: 2 nodes
# Cluster 476: 4 nodes
# Cluster 477: 2 nodes
# Cluster 478: 2 nodes
# Cluster 479: 1 nodes
# Cluster 480: 1 nodes
# Cluster 481: 1 nodes
# Cluster 482: 1 nodes
# Cluster 483: 3 nodes
# Cluster 484: 1 nodes
# Cluster 485: 1 nodes
# Cluster 486: 1 nodes
# Cluster 487: 1 nodes
# Cluster 488: 2 nodes
# Cluster 489: 1 nodes
# Cluster 490: 5 nodes
# Cluster 491: 2 nodes
# Cluster 492: 1 nodes
# Cluster 493: 2 nodes
# Cluster 494: 2 nodes
# Cluster 495: 2 nodes
# Cluster 496: 1 nodes
# Cluster 497: 1 nodes
# Cluster 498: 3 nodes
# Cluster 499: 6 nodes
# Cluster 500: 1 nodes
# Cluster 501: 2 nodes
# Cluster 502: 2 nodes
# Cluster 503: 1 nodes
# Cluster 504: 1 nodes
# Cluster 505: 1 nodes
# Cluster 506: 1 nodes
# Cluster 507: 1 nodes
# Cluster 508: 1 nodes
# Cluster 509: 1 nodes
# Cluster 510: 1 nodes
# Cluster 511: 2 nodes
# Cluster 512: 1 nodes
# Cluster 513: 1 nodes
# Cluster 514: 2 nodes
# Cluster 515: 1 nodes
# Cluster 516: 4 nodes
# Cluster 517: 1 nodes
# Cluster 518: 2 nodes
# Cluster 519: 1 nodes
# Cluster 520: 1 nodes
# Cluster 521: 3 nodes
# Cluster 522: 1 nodes
# Cluster 523: 1 nodes
# Cluster 524: 3 nodes
# Cluster 525: 4 nodes
# Cluster 526: 1 nodes
# Cluster 527: 6 nodes
# Cluster 528: 1 nodes
# Cluster 529: 1 nodes
# Cluster 530: 1 nodes
# Cluster 531: 1 nodes
# Cluster 532: 1 nodes
# Cluster 533: 3 nodes
# Cluster 534: 2 nodes
# Cluster 535: 2 nodes
# Cluster 536: 1 nodes
# Cluster 537: 1 nodes
# Cluster 538: 1 nodes
# Cluster 539: 6 nodes
# Cluster 540: 1 nodes
# Cluster 541: 3 nodes
# Cluster 542: 1 nodes
# Cluster 543: 1 nodes
# Cluster 544: 1 nodes
# Cluster 545: 1 nodes
# Cluster 546: 1 nodes
# Cluster 547: 1 nodes
# Cluster 548: 1 nodes
# Cluster 549: 2 nodes
# Cluster 550: 1 nodes
# Cluster 551: 1 nodes
# Cluster 552: 2 nodes
# Cluster 553: 1 nodes
# Cluster 554: 2 nodes
# Cluster 555: 2 nodes
# Cluster 556: 1 nodes
# Cluster 557: 2 nodes
# Cluster 558: 5 nodes
# Cluster 559: 1 nodes
# Cluster 560: 3 nodes
# Cluster 561: 1 nodes
# Cluster 562: 5 nodes
# Cluster 563: 2 nodes
# Cluster 564: 3 nodes
# Cluster 565: 1 nodes
# Cluster 566: 2 nodes
# Cluster 567: 2 nodes
# Cluster 568: 1 nodes
# Cluster 569: 2 nodes
# Cluster 570: 1 nodes
# Cluster 571: 1 nodes
# Cluster 572: 1 nodes
# Cluster 573: 1 nodes
# Cluster 574: 2 nodes
# Cluster 575: 1 nodes
# Cluster 576: 3 nodes
# Cluster 577: 1 nodes
# Cluster 578: 1 nodes
# Cluster 579: 1 nodes
# Cluster 580: 1 nodes
# Cluster 581: 1 nodes
# Cluster 582: 1 nodes
# Cluster 583: 1 nodes
# Cluster 584: 4 nodes
# Cluster 585: 1 nodes
# Cluster 586: 1 nodes
# Cluster 587: 1 nodes
# Cluster 588: 2 nodes
# Cluster 589: 2 nodes
# Cluster 590: 1 nodes
# Cluster 591: 1 nodes
# Cluster 592: 2 nodes
# Cluster 593: 1 nodes
# Cluster 594: 1 nodes
# Cluster 595: 3 nodes
# Cluster 596: 1 nodes
# Cluster 597: 1 nodes
# Cluster 598: 1 nodes
# Cluster 599: 2 nodes
# Cluster 600: 1 nodes
# Cluster 601: 4 nodes
# Cluster 602: 1 nodes
# Cluster 603: 1 nodes
# Cluster 604: 1 nodes
# Cluster 605: 1 nodes
# Cluster 606: 1 nodes
# Cluster 607: 2 nodes
# Cluster 608: 1 nodes
# Cluster 609: 2 nodes
# Cluster 610: 1 nodes
# Cluster 611: 1 nodes
# Cluster 612: 1 nodes
# Cluster 613: 1 nodes
# Cluster 614: 1 nodes
# Cluster 615: 1 nodes
# Cluster 616: 2 nodes
# Cluster 617: 1 nodes
# Cluster 618: 1 nodes
# Cluster 619: 2 nodes
# Cluster 620: 1 nodes
# Cluster 621: 1 nodes
# Cluster 622: 1 nodes
# Cluster 623: 1 nodes
# Cluster 624: 2 nodes
# Cluster 625: 1 nodes
# Cluster 626: 2 nodes
# Cluster 627: 1 nodes
# Cluster 628: 1 nodes
# Cluster 629: 1 nodes
# Cluster 630: 1 nodes
# Cluster 631: 1 nodes
# Cluster 632: 1 nodes
# Cluster 633: 2 nodes
# Cluster 634: 1 nodes
# Cluster 635: 5 nodes
# Cluster 636: 1 nodes
# Cluster 637: 1 nodes
# Cluster 638: 1 nodes
# Cluster 639: 1 nodes
# Cluster 640: 2 nodes
# Cluster 641: 6 nodes
# Cluster 642: 6 nodes
# Cluster 643: 1 nodes
# Cluster 644: 3 nodes
# Cluster 645: 1 nodes
# Cluster 646: 1 nodes
# Cluster 647: 1 nodes
# Cluster 648: 3 nodes
# Cluster 649: 1 nodes
# Cluster 650: 1 nodes
# Cluster 651: 1 nodes
# Cluster 652: 1 nodes
# Cluster 653: 4 nodes
# Cluster 654: 3 nodes
# Cluster 655: 1 nodes
# Cluster 656: 1 nodes
# Cluster 657: 1 nodes
# Cluster 658: 1 nodes
# Cluster 659: 2 nodes
# Cluster 660: 3 nodes
# Cluster 661: 3 nodes
# Cluster 662: 1 nodes
# Cluster 663: 3 nodes
# Cluster 664: 1 nodes
# Cluster 665: 1 nodes
# Cluster 666: 2 nodes
# Cluster 667: 2 nodes
# Cluster 668: 1 nodes
# Cluster 669: 1 nodes
# Cluster 670: 2 nodes
# Cluster 671: 2 nodes
# Cluster 672: 1 nodes
# Cluster 673: 1 nodes
# Cluster 674: 2 nodes
# Cluster 675: 4 nodes
# Cluster 676: 1 nodes
# Cluster 677: 1 nodes
# Cluster 678: 2 nodes
# Cluster 679: 1 nodes
# Cluster 680: 1 nodes
# Cluster 681: 2 nodes
# Cluster 682: 1 nodes
# Cluster 683: 2 nodes
# Cluster 684: 3 nodes
# Cluster 685: 1 nodes
# Cluster 686: 2 nodes
# Cluster 687: 1 nodes
# Cluster 688: 1 nodes
# Cluster 689: 2 nodes
# Cluster 690: 2 nodes
# Cluster 691: 1 nodes
# Cluster 692: 1 nodes
# Cluster 693: 1 nodes
# Cluster 694: 1 nodes
# Cluster 695: 3 nodes
# Cluster 696: 2 nodes
# Cluster 697: 1 nodes
# Cluster 698: 1 nodes
# Cluster 699: 1 nodes
# Cluster 700: 1 nodes
# Cluster 701: 1 nodes
# Cluster 702: 2 nodes
# Cluster 703: 1 nodes
# Cluster 704: 1 nodes
# Cluster 705: 1 nodes
# Cluster 706: 1 nodes
# Cluster 707: 4 nodes
# Cluster 708: 5 nodes
# Cluster 709: 1 nodes
# Cluster 710: 1 nodes
# Cluster 711: 1 nodes
# Cluster 712: 1 nodes
# Cluster 713: 1 nodes
# Cluster 714: 2 nodes
# Cluster 715: 1 nodes
# Cluster 716: 1 nodes
# Cluster 717: 1 nodes
# Cluster 718: 1 nodes
# Cluster 719: 3 nodes
# Cluster 720: 2 nodes
# Cluster 721: 1 nodes
# Cluster 722: 1 nodes
# Cluster 723: 2 nodes
# Cluster 724: 4 nodes
# Cluster 725: 1 nodes
# Cluster 726: 1 nodes
# Cluster 727: 1 nodes
# Cluster 728: 1 nodes
# Cluster 729: 2 nodes
# Cluster 730: 1 nodes
# Cluster 731: 1 nodes
# Cluster 732: 1 nodes
# Cluster 733: 2 nodes
# Cluster 734: 1 nodes
# Cluster 735: 1 nodes
# Cluster 736: 1 nodes
# Cluster 737: 1 nodes
# Cluster 738: 1 nodes
# Cluster 739: 1 nodes
# Cluster 740: 1 nodes
# Cluster 741: 1 nodes
# Cluster 742: 2 nodes
# Cluster 743: 1 nodes
# Cluster 744: 1 nodes
# Cluster 745: 1 nodes
# Cluster 746: 1 nodes
# Cluster 747: 1 nodes
# Cluster 748: 2 nodes
# Cluster 749: 1 nodes
# Cluster 750: 1 nodes
# Cluster 751: 1 nodes
# Cluster 752: 1 nodes
# Cluster 753: 2 nodes
# Cluster 754: 1 nodes
# Cluster 755: 2 nodes
# Cluster 756: 1 nodes
# Cluster 757: 1 nodes
# Cluster 758: 1 nodes
# Cluster 759: 1 nodes
# Cluster 760: 1 nodes
# Cluster 761: 1 nodes
# Cluster 762: 1 nodes
# Cluster 763: 2 nodes
# Cluster 764: 1 nodes
# Cluster 765: 2 nodes
# Cluster 766: 1 nodes
# Cluster 767: 1 nodes
# Cluster 768: 1 nodes
# Cluster 769: 1 nodes
# Cluster 770: 1 nodes
# Cluster 771: 1 nodes
# Cluster 772: 1 nodes
# Cluster 773: 1 nodes
# Cluster 774: 1 nodes
# Cluster 775: 1 nodes
# Cluster 776: 1 nodes
# Cluster 777: 1 nodes
# Cluster 778: 1 nodes
# Cluster 779: 1 nodes
# Cluster 780: 2 nodes
# Cluster 781: 3 nodes
# Cluster 782: 1 nodes
# Cluster 783: 3 nodes
# Cluster 784: 1 nodes
# Cluster 785: 1 nodes
# Cluster 786: 3 nodes
# Cluster 787: 1 nodes
# Cluster 788: 5 nodes
# Cluster 789: 2 nodes
# Cluster 790: 1 nodes
# Cluster 791: 1 nodes
# Cluster 792: 1 nodes
# Cluster 793: 1 nodes
# Cluster 794: 1 nodes
# Cluster 795: 1 nodes
# Cluster 796: 1 nodes
# Cluster 797: 2 nodes
# Cluster 798: 1 nodes
# Cluster 799: 1 nodes
# Cluster 800: 1 nodes
# Cluster 801: 1 nodes
# Cluster 802: 1 nodes
# Cluster 803: 1 nodes
# Cluster 804: 1 nodes
# Cluster 805: 1 nodes
# Cluster 806: 1 nodes
# Cluster 807: 1 nodes
# Cluster 808: 1 nodes
# Cluster 809: 1 nodes
# Cluster 810: 1 nodes
# Cluster 811: 1 nodes
# Cluster 812: 1 nodes
# Cluster 813: 6 nodes
# Cluster 814: 1 nodes
# Cluster 815: 1 nodes
# Cluster 816: 3 nodes
# Cluster 817: 1 nodes
# Cluster 818: 1 nodes
# Cluster 819: 1 nodes
# Cluster 820: 2 nodes
# Cluster 821: 1 nodes
# Cluster 822: 1 nodes
# Cluster 823: 1 nodes
# Cluster 824: 1 nodes
# Cluster 825: 5 nodes
# Cluster 826: 1 nodes
# Cluster 827: 1 nodes
# Cluster 828: 1 nodes
# Cluster 829: 2 nodes
# Cluster 830: 3 nodes
# Cluster 831: 1 nodes
# Cluster 832: 1 nodes
# Cluster 833: 2 nodes
# Cluster 834: 1 nodes
# Cluster 835: 2 nodes
# Cluster 836: 1 nodes
# Cluster 837: 1 nodes
# Cluster 838: 1 nodes
# Cluster 839: 1 nodes
# Cluster 840: 1 nodes
# Cluster 841: 1 nodes
# Cluster 842: 1 nodes
# Cluster 843: 1 nodes
# Cluster 844: 1 nodes
# Cluster 845: 1 nodes
# Cluster 846: 1 nodes
# Cluster 847: 1 nodes
# Cluster 848: 1 nodes
# Cluster 849: 1 nodes
# Cluster 850: 2 nodes
# Cluster 851: 1 nodes
# Cluster 852: 1 nodes
# Cluster 853: 1 nodes
# Cluster 854: 1 nodes
# Cluster 855: 1 nodes
# Cluster 856: 2 nodes
# Cluster 857: 1 nodes
# Cluster 858: 1 nodes
# Cluster 859: 1 nodes
# Cluster 860: 3 nodes
# Cluster 861: 1 nodes
# Cluster 862: 1 nodes
# Cluster 863: 1 nodes
# Cluster 864: 1 nodes
# Cluster 865: 2 nodes
# Cluster 866: 1 nodes
# Cluster 867: 1 nodes
# Cluster 868: 1 nodes
# Cluster 869: 1 nodes
# Cluster 870: 1 nodes
# Cluster 871: 1 nodes
# Cluster 872: 1 nodes
# Cluster 873: 1 nodes
# Cluster 874: 1 nodes
# Cluster 875: 1 nodes
# Cluster 876: 2 nodes
# Cluster 877: 1 nodes
# Cluster 878: 1 nodes
# Cluster 879: 1 nodes
# Cluster 880: 1 nodes
# Cluster 881: 1 nodes
# Cluster 882: 2 nodes
# Cluster 883: 1 nodes
# Cluster 884: 1 nodes
# Cluster 885: 1 nodes
# Cluster 886: 1 nodes
# Cluster 887: 1 nodes
# Cluster 888: 1 nodes
# Cluster 889: 1 nodes
# Cluster 890: 1 nodes
# Cluster 891: 2 nodes
# Cluster 892: 1 nodes
# Cluster 893: 2 nodes
# Cluster 894: 1 nodes
# Cluster 895: 1 nodes
# Cluster 896: 1 nodes
# Cluster 897: 1 nodes
# Cluster 898: 1 nodes
# Cluster 899: 1 nodes
# Cluster 900: 1 nodes
# Cluster 901: 1 nodes
# Cluster 902: 1 nodes
# Cluster 903: 2 nodes
# Cluster 904: 2 nodes
# Cluster 905: 1 nodes
# Cluster 906: 1 nodes
# Cluster 907: 1 nodes
# Cluster 908: 1 nodes
# Cluster 909: 1 nodes
# Cluster 910: 1 nodes
# Cluster 911: 2 nodes
# Cluster 912: 1 nodes
# Cluster 913: 1 nodes
# Cluster 914: 1 nodes
# Cluster 915: 2 nodes
# Cluster 916: 2 nodes
# Cluster 917: 1 nodes
# Cluster 918: 1 nodes
# Cluster 919: 1 nodes
# Cluster 920: 2 nodes
# Cluster 921: 1 nodes
# Cluster 922: 1 nodes
# Cluster 923: 1 nodes
# Cluster 924: 1 nodes
# Cluster 925: 1 nodes
# Cluster 926: 2 nodes
# Cluster 927: 1 nodes
# Cluster 928: 2 nodes
# Cluster 929: 1 nodes
# Cluster 930: 1 nodes
# Cluster 931: 1 nodes
# Cluster 932: 1 nodes
# Cluster 933: 1 nodes
# Cluster 934: 1 nodes
# Cluster 935: 1 nodes
# Cluster 936: 1 nodes
# Cluster 937: 1 nodes
# Cluster 938: 1 nodes
# Cluster 939: 1 nodes
# Cluster 940: 1 nodes
# Cluster 941: 1 nodes
# Cluster 942: 1 nodes
# Cluster 943: 1 nodes
# Cluster 944: 1 nodes
# Cluster 945: 1 nodes
# Cluster 946: 1 nodes
# Cluster 947: 1 nodes
# Cluster 948: 1 nodes
# Cluster 949: 3 nodes
# Cluster 950: 1 nodes
# Cluster 951: 1 nodes
# Cluster 952: 1 nodes
# Cluster 953: 1 nodes
# Cluster 954: 1 nodes
# Cluster 955: 1 nodes
# Cluster 956: 1 nodes
# Cluster 957: 2 nodes
# Cluster 958: 1 nodes
# Cluster 959: 1 nodes
# Cluster 960: 1 nodes
# Cluster 961: 1 nodes
# Cluster 962: 1 nodes
# Cluster 963: 1 nodes
# Cluster 964: 1 nodes
# Cluster 965: 2 nodes
# Cluster 966: 1 nodes
# Cluster 967: 1 nodes
# Cluster 968: 1 nodes
# Cluster 969: 1 nodes
# Cluster 970: 1 nodes
# Cluster 971: 1 nodes
# Cluster 972: 1 nodes
# Cluster 973: 1 nodes
# Cluster 974: 1 nodes
# Cluster 975: 1 nodes
# Cluster 976: 1 nodes
# Cluster 977: 1 nodes
# Cluster 978: 1 nodes
# Cluster 979: 1 nodes
# Cluster 980: 1 nodes
# Cluster 981: 1 nodes
# Cluster 982: 1 nodes
# Cluster 983: 1 nodes
# Cluster 984: 1 nodes
# Cluster 985: 1 nodes
# Cluster 986: 3 nodes
# Cluster 987: 2 nodes
# Cluster 988: 1 nodes
# Cluster 989: 1 nodes
# Cluster 990: 3 nodes
# Cluster 991: 1 nodes
# Cluster 992: 1 nodes
# Cluster 993: 1 nodes
# Cluster 994: 1 nodes
# Cluster 995: 1 nodes
# Cluster 996: 2 nodes
# Cluster 997: 1 nodes
# Cluster 998: 1 nodes
# Cluster 999: 1 nodes
# Cluster 1000: 1 nodes
# Cluster 1001: 1 nodes
# Cluster 1002: 1 nodes
# Cluster 1003: 1 nodes
# Cluster 1004: 1 nodes
# Cluster 1005: 1 nodes
# Cluster 1006: 1 nodes
# Cluster 1007: 1 nodes
# Cluster 1008: 1 nodes
# Cluster 1009: 1 nodes
# Cluster 1010: 1 nodes
# Cluster 1011: 1 nodes
# Cluster 1012: 1 nodes
# Cluster 1013: 1 nodes
# Cluster 1014: 1 nodes
# Cluster 1015: 1 nodes
# Cluster 1016: 1 nodes
# Cluster 1017: 1 nodes
# Cluster 1018: 1 nodes
# Cluster 1019: 1 nodes
# Cluster 1020: 1 nodes
# Cluster 1021: 1 nodes
# Cluster 1022: 1 nodes
# Cluster 1023: 1 nodes
# Cluster 1024: 1 nodes
# Cluster 1025: 1 nodes
# Cluster 1026: 2 nodes
# Cluster 1027: 1 nodes
# Cluster 1028: 1 nodes
# Cluster 1029: 1 nodes
# Cluster 1030: 1 nodes
# Cluster 1031: 1 nodes
# Cluster 1032: 1 nodes
# Cluster 1033: 1 nodes
# Cluster 1034: 1 nodes
# Cluster 1035: 1 nodes
# Cluster 1036: 1 nodes
# Cluster 1037: 1 nodes
# Cluster 1038: 1 nodes
# Cluster 1039: 1 nodes
# Cluster 1040: 1 nodes
# Cluster 1041: 1 nodes
# Cluster 1042: 1 nodes
# Cluster 1043: 1 nodes
# Cluster 1044: 1 nodes
# Cluster 1045: 1 nodes
# Cluster 1046: 1 nodes
# Cluster 1047: 1 nodes
# Cluster 1048: 1 nodes
# Cluster 1049: 1 nodes
# Cluster 1050: 1 nodes
# Cluster 1051: 1 nodes
# Cluster 1052: 2 nodes
# Cluster 1053: 1 nodes
# Cluster 1054: 1 nodes
# Cluster 1055: 1 nodes
# Cluster 1056: 1 nodes
# Cluster 1057: 1 nodes
# Cluster 1058: 1 nodes
# Cluster 1059: 1 nodes
# Cluster 1060: 1 nodes
# Cluster 1061: 1 nodes
# Cluster 1062: 1 nodes
# Cluster 1063: 1 nodes
# Cluster 1064: 1 nodes
# Cluster 1065: 1 nodes
# Cluster 1066: 1 nodes
# Cluster 1067: 1 nodes
# Cluster 1068: 1 nodes
# Cluster 1069: 1 nodes
# Cluster 1070: 1 nodes
# Cluster 1071: 1 nodes
# Cluster 1072: 1 nodes
# Cluster 1073: 1 nodes
# Cluster 1074: 1 nodes
# Cluster 1075: 2 nodes
# Cluster 1076: 1 nodes
# Cluster 1077: 1 nodes
# Cluster 1078: 1 nodes
# Cluster 1079: 1 nodes
# Cluster 1080: 1 nodes
# Cluster 1081: 1 nodes
# Cluster 1082: 1 nodes
# Cluster 1083: 1 nodes
# Cluster 1084: 1 nodes
# Cluster 1085: 2 nodes
# Cluster 1086: 1 nodes
# Cluster 1087: 1 nodes
# Cluster 1088: 1 nodes
# Cluster 1089: 1 nodes
# Cluster 1090: 1 nodes
# Cluster 1091: 2 nodes
# Cluster 1092: 1 nodes
# Cluster 1093: 1 nodes
# Cluster 1094: 1 nodes
# Cluster 1095: 1 nodes
# Cluster 1096: 1 nodes
# Cluster 1097: 2 nodes
# Cluster 1098: 1 nodes
# Cluster 1099: 2 nodes
# Cluster 1100: 1 nodes
# Cluster 1101: 2 nodes
# Cluster 1102: 3 nodes
# Cluster 1103: 1 nodes
# Cluster 1104: 1 nodes
# Cluster 1105: 1 nodes
# Cluster 1106: 1 nodes
# Cluster 1107: 1 nodes
# Cluster 1108: 1 nodes
# Cluster 1109: 1 nodes
# Cluster 1110: 1 nodes
# Cluster 1111: 1 nodes
# Cluster 1112: 1 nodes
# Cluster 1113: 1 nodes
# Cluster 1114: 1 nodes
# Cluster 1115: 1 nodes
# Cluster 1116: 2 nodes
# Cluster 1117: 1 nodes
# Cluster 1118: 1 nodes
# Cluster 1119: 1 nodes
# Cluster 1120: 1 nodes
# Cluster 1121: 1 nodes
# Cluster 1122: 1 nodes
# Cluster 1123: 1 nodes
# Cluster 1124: 1 nodes
# Cluster 1125: 1 nodes
# Cluster 1126: 1 nodes
# Cluster 1127: 1 nodes
# Cluster 1128: 2 nodes
# Cluster 1129: 1 nodes
# Cluster 1130: 2 nodes
# Cluster 1131: 1 nodes
# Cluster 1132: 1 nodes
# Cluster 1133: 2 nodes
# Cluster 1134: 1 nodes
# Cluster 1135: 1 nodes
# Cluster 1136: 1 nodes
# Cluster 1137: 1 nodes
# Cluster 1138: 1 nodes
# Cluster 1139: 1 nodes
# Cluster 1140: 1 nodes
# Cluster 1141: 1 nodes
# Cluster 1142: 1 nodes
# Cluster 1143: 1 nodes
# Cluster 1144: 1 nodes
# Cluster 1145: 1 nodes
# Cluster 1146: 1 nodes
# Cluster 1147: 1 nodes
# Cluster 1148: 1 nodes
# Cluster 1149: 1 nodes
# Cluster 1150: 1 nodes
# Cluster 1151: 2 nodes
# Cluster 1152: 1 nodes
# Cluster 1153: 1 nodes
# Cluster 1154: 1 nodes
# Cluster 1155: 1 nodes
# Cluster 1156: 1 nodes
# Cluster 1157: 1 nodes
# Cluster 1158: 1 nodes
# Cluster 1159: 1 nodes
# Cluster 1160: 1 nodes
# Cluster 1161: 1 nodes
# Cluster 1162: 1 nodes
# Cluster 1163: 1 nodes
# Cluster 1164: 1 nodes
# Cluster 1165: 2 nodes
# Cluster 1166: 1 nodes
# Cluster 1167: 1 nodes
# Cluster 1168: 1 nodes
# Cluster 1169: 2 nodes
# Cluster 1170: 1 nodes
# Cluster 1171: 1 nodes
# Cluster 1172: 1 nodes
# Cluster 1173: 1 nodes
# Cluster 1174: 1 nodes
# Cluster 1175: 1 nodes
# Cluster 1176: 1 nodes
# Cluster 1177: 1 nodes
# Cluster 1178: 1 nodes
# Cluster 1179: 1 nodes
# Cluster 1180: 1 nodes
# Cluster 1181: 1 nodes
# Cluster 1182: 1 nodes
# Cluster 1183: 1 nodes
# Cluster 1184: 1 nodes
# Cluster 1185: 1 nodes
# Cluster 1186: 1 nodes
# Cluster 1187: 1 nodes
# Cluster 1188: 1 nodes
# Cluster 1189: 1 nodes
# Cluster 1190: 2 nodes
# Cluster 1191: 1 nodes
# Cluster 1192: 2 nodes
# Cluster 1193: 1 nodes
# Cluster 1194: 1 nodes
# Cluster 1195: 1 nodes
# Cluster 1196: 1 nodes
# Cluster 1197: 1 nodes
# Cluster 1198: 1 nodes
# Cluster 1199: 1 nodes
# Cluster 1200: 1 nodes
# Cluster 1201: 1 nodes
# Cluster 1202: 1 nodes
# Cluster 1203: 1 nodes
# Cluster 1204: 1 nodes
# Cluster 1205: 1 nodes
# Cluster 1206: 2 nodes
# Cluster 1207: 1 nodes
# Cluster 1208: 1 nodes
# Cluster 1209: 1 nodes
# Cluster 1210: 1 nodes
# Cluster 1211: 1 nodes
# Cluster 1212: 1 nodes
# Cluster 1213: 1 nodes
# Cluster 1214: 1 nodes
# Cluster 1215: 1 nodes
# Cluster 1216: 1 nodes
# Cluster 1217: 1 nodes
# Cluster 1218: 1 nodes
# Cluster 1219: 2 nodes
# Cluster 1220: 1 nodes
# Cluster 1221: 1 nodes
# Cluster 1222: 1 nodes
# Cluster 1223: 1 nodes
# Cluster 1224: 1 nodes
# Cluster 1225: 1 nodes
# Cluster 1226: 1 nodes
# Cluster 1227: 1 nodes
# Cluster 1228: 1 nodes
# Cluster 1229: 1 nodes
# Cluster 1230: 1 nodes
# Cluster 1231: 1 nodes
# Cluster 1232: 1 nodes
# Cluster 1233: 1 nodes
# Cluster 1234: 1 nodes
# Cluster 1235: 1 nodes
# Cluster 1236: 1 nodes
# Cluster 1237: 1 nodes
# Cluster 1238: 1 nodes
# Cluster 1239: 1 nodes
# Cluster 1240: 1 nodes
# Cluster 1241: 1 nodes
# Cluster 1242: 1 nodes
# Cluster 1243: 1 nodes
# Cluster 1244: 1 nodes
# Cluster 1245: 1 nodes
# Cluster 1246: 1 nodes
# Cluster 1247: 1 nodes
# Cluster 1248: 1 nodes
# Cluster 1249: 1 nodes
# Cluster 1250: 1 nodes
# Cluster 1251: 1 nodes
# Cluster 1252: 1 nodes
# Cluster 1253: 1 nodes
# Cluster 1254: 1 nodes
# Cluster 1255: 1 nodes
# Cluster 1256: 1 nodes
# Cluster 1257: 1 nodes
# Cluster 1258: 1 nodes
# Cluster 1259: 1 nodes
# Cluster 1260: 1 nodes
# Cluster 1261: 1 nodes
# Cluster 1262: 1 nodes
# Cluster 1263: 1 nodes
# Cluster 1264: 1 nodes
# Cluster 1265: 1 nodes
# Cluster 1266: 1 nodes
# Cluster 1267: 1 nodes
# Cluster 1268: 1 nodes
# Cluster 1269: 1 nodes
# Cluster 1270: 1 nodes
# Cluster 1271: 1 nodes
# Cluster 1272: 1 nodes
# Cluster 1273: 1 nodes
# Cluster 1274: 1 nodes
# Cluster 1275: 1 nodes
# Cluster 1276: 1 nodes
# Cluster 1277: 1 nodes
# Cluster 1278: 1 nodes
# Cluster 1279: 1 nodes
# Cluster 1280: 1 nodes
# Cluster 1281: 1 nodes
# Cluster 1282: 1 nodes
# Cluster 1283: 1 nodes
# Cluster 1284: 1 nodes
# Cluster 1285: 1 nodes
# Cluster 1286: 1 nodes
# Cluster 1287: 1 nodes
# Cluster 1288: 1 nodes
# Cluster 1289: 1 nodes
# Cluster 1290: 1 nodes
# Cluster 1291: 1 nodes
# Cluster 1292: 1 nodes
# Cluster 1293: 1 nodes
# Cluster 1294: 1 nodes
# Cluster 1295: 1 nodes
# Cluster 1296: 1 nodes
# Cluster 1297: 1 nodes
# Cluster 1298: 1 nodes
# Cluster 1299: 1 nodes
# Cluster 1300: 2 nodes
# Cluster 1301: 2 nodes
# Cluster 1302: 1 nodes
# Cluster 1303: 1 nodes
# Cluster 1304: 1 nodes
# Cluster 1305: 1 nodes
# Cluster 1306: 1 nodes
# Cluster 1307: 1 nodes
# Cluster 1308: 1 nodes
# Cluster 1309: 1 nodes
# Cluster 1310: 1 nodes
# Cluster 1311: 1 nodes
# Cluster 1312: 1 nodes
# Cluster 1313: 1 nodes
# Cluster 1314: 1 nodes
# Cluster 1315: 1 nodes
# Cluster 1316: 1 nodes
# Cluster 1317: 1 nodes
# Cluster 1318: 1 nodes
# Cluster 1319: 1 nodes
# Cluster 1320: 1 nodes
# Cluster 1321: 1 nodes
# Cluster 1322: 1 nodes
# Cluster 1323: 1 nodes

# %%
import numpy as np
import torch
import matplotlib.pyplot as plt
from sklearn.neighbors import NearestNeighbors
from sklearn.manifold import TSNE
import networkx as nx

def visualize_threshold_graph(unique_vectors, distance_threshold):
    """
    Builds and visualizes a graph where each unique vector is a node and an edge is added
    between nodes if their Euclidean distance is <= distance_threshold.

    The visualization uses t-SNE to embed the nodes into 2D (to mimic a Kepler Mapper style).

    Args:
        unique_vectors (torch.Tensor or np.array): Array/tensor of shape (n, 784) containing unique images.
        distance_threshold (float): Maximum Euclidean distance for adding an edge between two nodes.
    """
    # Convert tensor to numpy array if necessary.
    if hasattr(unique_vectors, 'cpu'):
        X = unique_vectors.cpu().numpy()
    else:
        X = unique_vectors

    n = X.shape[0]
    print(f"Building graph for {n} nodes...")

    # Use NearestNeighbors to find all pairs within the distance threshold
    nbrs = NearestNeighbors(radius=distance_threshold, algorithm='ball_tree').fit(X)
    # indices[i] is an array of indices of neighbors for node i (including itself)
    distances, indices = nbrs.radius_neighbors(X)

    # Create an undirected graph and add nodes
    G = nx.Graph()
    G.add_nodes_from(range(n))

    # Add edges: For each node, add an edge to every neighbor with index > current node (to avoid duplicates)
    for i, neigh in enumerate(indices):
        for j in neigh:
            if i < j:
                G.add_edge(i, j)
    print(f"Graph built with {G.number_of_edges()} edges.")

    # Compute a 2D embedding for visualization using t-SNE.
    print("Computing 2D embedding with t-SNE...")
    X_reduced = TSNE(n_components=2, random_state=42).fit_transform(X)
    pos = {i: X_reduced[i] for i in range(n)}

    # Plot the graph
    plt.figure(figsize=(12, 10))
    nx.draw_networkx_nodes(G, pos, node_size=10, node_color='blue', alpha=0.6)
    nx.draw_networkx_edges(G, pos, alpha=0.3)
    plt.title(f"Graph of Unique Vectors (Edges if distance <= {distance_threshold})")
    plt.axis('off')
    plt.show()

    return G

G = visualize_threshold_graph(unique_vectors, distance_threshold=3.5)
# Out:
# Building graph for 6726 nodes...
# Graph built with 92855 edges.
# Computing 2D embedding with t-SNE...

# %%
# # Install PyVis if not already installed (uncomment the next line if needed)
# !pip install pyvis

# # Convert node IDs in G to native Python ints
# def convert_graph_node_ids_to_int(G):
#     H = nx.Graph()
#     # Convert nodes
#     for node, data in G.nodes(data=True):
#         H.add_node(int(node), **data)
#     # Convert edges
#     for u, v, data in G.edges(data=True):
#         H.add_edge(int(u), int(v), **data)
#     return H

# G_int = convert_graph_node_ids_to_int(G)

# # Now visualize using PyVis as before
# from pyvis.network import Network

# def visualize_graph_html(G, output_filename="graph.html", notebook=True):
#     net = Network(notebook=notebook, height="800px", width="100%", bgcolor="#222222", font_color="white")
#     net.from_nx(G)
#     net.show_buttons(filter_=['physics'])
#     net.show(output_filename)

# visualize_graph_html(G_int, output_filename="unique_vectors_graph.html")

# %%
# Get all connected components as a list of sets
components = list(nx.connected_components(G))
print(f"Total connected components: {len(components)}")

# Filter components that have more than 5 nodes
large_components = [(i, comp) for i, comp in enumerate(components) if len(comp) > 5]

# Print each large component's index and size
for comp_idx, comp in large_components:
    print(f"Component {comp_idx}: {len(comp)} nodes")
# Out:
# Total connected components: 1142
# Component 13: 5493 nodes
# Component 270: 6 nodes
# Component 492: 7 nodes

# %%
# Extract the main component (largest connected component) from G
main_component_nodes = max(nx.connected_components(G), key=len)
G_main = G.subgraph(main_component_nodes)

print(f"Main component has {G_main.number_of_nodes()} nodes and {G_main.number_of_edges()} edges.")

# --- 1. Cycle Basis (Cyclomatic Number) ---
# The cycle basis is a minimal set of cycles from which every cycle in the graph can be formed.
cycle_basis = nx.cycle_basis(G_main)
cyclomatic_number = len(cycle_basis)
print(f"Cyclomatic number (number of independent cycles) in the main component: {cyclomatic_number}")

# --- 2. Maximal Cliques ---
# A clique is a subset of nodes where every two nodes are connected.
# Finding all maximal cliques can be expensive for very large graphs.
print("Computing maximal cliques in the main component (this may take some time)...")
maximal_cliques = list(nx.find_cliques(G_main))
print(f"Number of maximal cliques in the main component: {len(maximal_cliques)}")

# Optionally, if you want to inspect the sizes of the largest cliques:
clique_sizes = [len(clique) for clique in maximal_cliques]
print(f"Max clique size: {max(clique_sizes)}; Average clique size: {np.mean(clique_sizes):.2f}")
# Out:
# Main component has 5493 nodes and 92758 edges.
# Cyclomatic number (number of independent cycles) in the main component: 87266
# Computing maximal cliques in the main component (this may take some time)...
# Number of maximal cliques in the main component: 92477
# Max clique size: 65; Average clique size: 14.62

# %%
# prompt: make bar graph of how many elements in maximal_cliques have 1 to 65 elements

import matplotlib.pyplot as plt
import networkx as nx

# Assuming 'maximal_cliques' is defined from your previous code
clique_sizes = [len(clique) for clique in maximal_cliques]

# Count the number of cliques with 1 to 65 elements
counts = [0] * 65
for size in clique_sizes:
  if size <= 65:
    counts[size - 1] += 1

# Create a bar graph
plt.figure(figsize=(15, 5))
plt.bar(range(1, 66), counts)
plt.xlabel("Number of elements in a maximal clique")
plt.ylabel("Number of cliques")
plt.title("Distribution of Maximal Clique Sizes")
plt.show()

# %%
import numpy as np
import random
import matplotlib.pyplot as plt

def jaccard_similarity(clique1, clique2):
    s1 = set(clique1)
    s2 = set(clique2)
    union = s1 | s2
    if not union:
        return 0.0
    return len(s1 & s2) / len(union)

# Number of samples to take
sample_size = 10000
num_cliques = len(maximal_cliques)
similarities = []

# Sample sample_size random pairs (i, j) with i < j
for _ in range(sample_size):
    i = random.randint(0, num_cliques - 2)
    j = random.randint(i + 1, num_cliques - 1)
    sim = jaccard_similarity(maximal_cliques[i], maximal_cliques[j])
    similarities.append(sim)

similarities = np.array(similarities)

print("Sampled", len(similarities), "pairwise Jaccard similarities.")
print("Mean similarity:", similarities.mean())
print("Median similarity:", np.median(similarities))
print("Min similarity:", similarities.min())
print("Max similarity:", similarities.max())

plt.figure(figsize=(10,5))
plt.hist(similarities, bins=50, color='skyblue', edgecolor='black')
plt.xlabel("Jaccard Similarity")
plt.ylabel("Frequency")
plt.title("Histogram of Sampled Pairwise Jaccard Similarities Among Maximal Cliques")
plt.show()
# Out:
# Sampled 10000 pairwise Jaccard similarities.
# Mean similarity: 0.02172893587565392
# Median similarity: 0.0
# Min similarity: 0.0
# Max similarity: 0.7619047619047619

# %%
import matplotlib.pyplot as plt
import numpy as np

def record_coverage_by_cliques(maximal_cliques, total_nodes, thresholds=[0.25, 0.50, 0.75, 1.0]):
    """
    Given a list of maximal cliques and the total number of nodes in the component,
    this function sorts the cliques (largest first) and iterates over them, marking
    nodes as "seen." When the cumulative coverage reaches each threshold, it records
    the number of cliques used and the size of the clique that achieved that threshold.

    Args:
        maximal_cliques (list of lists): Each element is a list of node IDs in that clique.
        total_nodes (int): Total number of nodes in the component.
        thresholds (list of floats): Fractions (between 0 and 1) at which to record coverage.

    Returns:
        results (dict): Keys are thresholds (as a fraction) and values are tuples:
                        (num_cliques_used, size_of_last_clique, cumulative_nodes_seen)
    """
    # Sort cliques in descending order by their size
    sorted_cliques = sorted(maximal_cliques, key=lambda clique: len(clique), reverse=True)

    seen = set()
    results = {}
    clique_count = 0

    # Work through thresholds in ascending order for recording
    threshold_targets = sorted(thresholds)

    for clique in sorted_cliques:
        clique_count += 1
        seen.update(clique)
        current_coverage = len(seen)
        current_fraction = current_coverage / total_nodes

        # Record any thresholds that have just been reached or passed
        while threshold_targets and current_fraction >= threshold_targets[0]:
            threshold = threshold_targets.pop(0)
            results[threshold] = (clique_count, len(clique), current_coverage)

        if not threshold_targets:
            break

    return results

# Assuming G_main is your main component subgraph and maximal_cliques were computed from it:
total_nodes = G_main.number_of_nodes()  # total nodes in the main component
results = record_coverage_by_cliques(maximal_cliques, total_nodes)

# Print the results
for threshold in sorted(results.keys()):
    num_cliques, clique_size, seen_nodes = results[threshold]
    print(f"{int(threshold*100)}% coverage: {num_cliques} cliques used, "
          f"last clique had {clique_size} nodes, total nodes seen: {seen_nodes} out of {total_nodes}")

# Optionally, create bar graphs for visualization:
threshold_labels = [f"{int(threshold*100)}%" for threshold in sorted(results.keys())]
num_cliques_list = [results[thr][0] for thr in sorted(results.keys())]
last_clique_sizes = [results[thr][1] for thr in sorted(results.keys())]

plt.figure(figsize=(10, 5))
plt.bar(threshold_labels, num_cliques_list, color='skyblue')
plt.xlabel("Coverage Threshold")
plt.ylabel("Number of Cliques Used")
plt.title("Number of Maximal Cliques Needed for Coverage")
plt.show()

plt.figure(figsize=(10, 5))
plt.bar(threshold_labels, last_clique_sizes, color='salmon')
plt.xlabel("Coverage Threshold")
plt.ylabel("Size of Last Clique Added")
plt.title("Size of the Clique Achieving Each Coverage Threshold")
plt.show()
# Out:
# 25% coverage: 37411 cliques used, last clique had 15 nodes, total nodes seen: 1374 out of 5493
# 50% coverage: 67844 cliques used, last clique had 8 nodes, total nodes seen: 2747 out of 5493
# 75% coverage: 86567 cliques used, last clique had 5 nodes, total nodes seen: 4120 out of 5493
# 100% coverage: 92477 cliques used, last clique had 2 nodes, total nodes seen: 5493 out of 5493

# %%
# import numpy as np
# import matplotlib.pyplot as plt

# def jaccard_similarity(clique1, clique2):
#     set1 = set(clique1)
#     set2 = set(clique2)
#     inter = len(set1.intersection(set2))
#     union = len(set1.union(set2))
#     return inter / union if union > 0 else 0

# # Compute pairwise Jaccard similarities between all maximal cliques.
# pairwise_similarities = []
# num_cliques = len(maximal_cliques)
# for i in range(num_cliques):
#     for j in range(i + 1, num_cliques):
#         sim = jaccard_similarity(maximal_cliques[i], maximal_cliques[j])
#         pairwise_similarities.append(sim)

# pairwise_similarities = np.array(pairwise_similarities)
# print(f"Computed {len(pairwise_similarities)} pairwise similarities.")
# print("Min similarity:", pairwise_similarities.min())
# print("Max similarity:", pairwise_similarities.max())
# print("Mean similarity:", pairwise_similarities.mean())
# print("Median similarity:", np.median(pairwise_similarities))

# # Plot histogram of the pairwise Jaccard similarities.
# plt.figure(figsize=(10, 5))
# plt.hist(pairwise_similarities, bins=50, color='skyblue', edgecolor='black')
# plt.xlabel("Jaccard Similarity")
# plt.ylabel("Frequency")
# plt.title("Histogram of Pairwise Jaccard Similarities Among Maximal Cliques")
# plt.show()

# %%
# import numpy as np
# import random
# import matplotlib.pyplot as plt

# def jaccard_similarity(clique1, clique2):
#     set1 = set(clique1)
#     set2 = set(clique2)
#     inter = len(set1.intersection(set2))
#     union = len(set1.union(set2))
#     return inter / union if union > 0 else 0

# # Subsample a fixed number of pairs instead of computing all pairs.
# sample_size = 10000  # Adjust this number as needed.
# num_cliques = len(maximal_cliques)
# pairwise_similarities = []

# # Ensure there are enough pairs available.
# max_possible_pairs = num_cliques * (num_cliques - 1) // 2
# if sample_size > max_possible_pairs:
#     sample_size = max_possible_pairs

# # Weighted sampling of clique pairs based on size
# weights = [len(c) for c in maximal_cliques]
# for _ in range(sample_size):
#     i = random.choices(range(num_cliques), weights=weights, k=1)[0]
#     j = random.choices(range(num_cliques), weights=weights, k=1)[0]
#     if i != j:
#         sim = jaccard_similarity(maximal_cliques[i], maximal_cliques[j])
#         pairwise_similarities.append(sim)


# pairwise_similarities = np.array(pairwise_similarities)
# print(f"Computed {len(pairwise_similarities)} pairwise similarities (sampled).")
# print("Min similarity:", pairwise_similarities.min())
# print("Max similarity:", pairwise_similarities.max())
# print("Mean similarity:", pairwise_similarities.mean())
# print("Median similarity:", np.median(pairwise_similarities))

# # Plot histogram of the sampled pairwise Jaccard similarities.
# plt.figure(figsize=(10, 5))
# plt.hist(pairwise_similarities, bins=50, color='skyblue', edgecolor='black')
# plt.xlabel("Jaccard Similarity")
# plt.ylabel("Frequency")
# plt.title("Histogram of Sampled Pairwise Jaccard Similarities Among Maximal Cliques")
# plt.show()

# %%
import random
import matplotlib.pyplot as plt
import torch

# Assume G (the graph) and unique_vectors (tensor of shape [n, 784]) are defined

# Get all connected components and select component 13 (as printed previously)
components = list(nx.connected_components(G))
# Option 1: Use the 14th component in the list (index 13)
component_13 = list(components[13])
# Alternatively, if not sure, you could choose the largest component:
# component_13 = list(max(components, key=len))

# Randomly choose one node from component 13 as the center
center_node = random.choice(component_13)

# Get neighbors of the center node
neighbors = list(G.neighbors(center_node))
if len(neighbors) < 5:
    selected_neighbors = neighbors  # if fewer than 5, use them all
else:
    selected_neighbors = random.sample(neighbors, 5)

# Get the center image from unique_vectors and reshape to 28x28
center_image = unique_vectors[center_node]
center_image_reshaped = center_image.view(28, 28)

# Interpolation factors to use
factors = [0.25, 0.5, 0.75]

# Prepare a plot: one row per selected neighbor, each row has 5 images
num_rows = len(selected_neighbors)
num_cols = 5
fig, axs = plt.subplots(num_rows, num_cols, figsize=(15, 3 * num_rows))

# If only one row, force axs to be 2D for consistent indexing
if num_rows == 1:
    axs = [axs]

for row, neighbor in enumerate(selected_neighbors):
    neighbor_image = unique_vectors[neighbor]
    neighbor_image_reshaped = neighbor_image.view(28, 28)

    # Compute interpolated images
    interpolated_images = []
    for t in factors:
        interp_img = (1 - t) * center_image + t * neighbor_image
        interpolated_images.append(interp_img.view(28, 28))

    # Plot each row:
    # Column 0: the center image
    axs[row][0].imshow(center_image_reshaped, cmap='gray')
    axs[row][0].set_title("Center")
    axs[row][0].axis('off')

    # Columns 1-3: interpolated images at 25%, 50%, 75%
    for j, interp_img in enumerate(interpolated_images, start=1):
        axs[row][j].imshow(interp_img, cmap='gray')
        axs[row][j].set_title(f"{int(factors[j-1]*100)}%")
        axs[row][j].axis('off')

    # Column 4: the neighbor image
    axs[row][4].imshow(neighbor_image_reshaped, cmap='gray')
    axs[row][4].set_title("Neighbor")
    axs[row][4].axis('off')

plt.tight_layout()
plt.show()

# %%
import random
import matplotlib.pyplot as plt
import torch

# --- Step 1: Get the biggest maximal clique ---
biggest_clique = max(maximal_cliques, key=len)
print(f"Biggest clique has {len(biggest_clique)} nodes")

# Ensure biggest_clique is a list (if not already)
biggest_clique = list(biggest_clique)

# --- Step 2: Randomly choose a center node from the biggest clique ---
center_node = random.choice(biggest_clique)
center_image = unique_vectors[center_node]
center_image_reshaped = center_image.view(28, 28)

# --- Step 3: Randomly sample up to 5 neighbors from the clique (excluding the center) ---
neighbors = [node for node in biggest_clique if node != center_node]
if len(neighbors) < 5:
    sampled_neighbors = neighbors
else:
    sampled_neighbors = random.sample(neighbors, 5)

# --- Step 4: For each neighbor, compute 25%, 50%, and 75% interpolations ---
factors = [0.25, 0.5, 0.75]
num_rows = len(sampled_neighbors)
num_cols = 5  # Columns: Center, 25%, 50%, 75%, Neighbor

# Create subplots
fig, axs = plt.subplots(num_rows, num_cols, figsize=(15, 3 * num_rows))

# If there's only one row, ensure axs is 2D for consistent indexing
if num_rows == 1:
    axs = [axs]

for row, neighbor in enumerate(sampled_neighbors):
    neighbor_image = unique_vectors[neighbor]
    neighbor_image_reshaped = neighbor_image.view(28, 28)

    # Compute interpolated images
    interpolated_images = []
    for t in factors:
        interp_img = (1 - t) * center_image + t * neighbor_image
        interpolated_images.append(interp_img.view(28, 28))

    # --- Step 5: Plot the images in one row ---
    # Column 0: Center image
    axs[row][0].imshow(center_image_reshaped, cmap='gray')
    axs[row][0].set_title("Center")
    axs[row][0].axis('off')

    # Columns 1-3: Interpolated images at 25%, 50%, 75%
    for j, interp_img in enumerate(interpolated_images, start=1):
        axs[row][j].imshow(interp_img, cmap='gray')
        axs[row][j].set_title(f"{int(factors[j-1]*100)}%")
        axs[row][j].axis('off')

    # Column 4: Neighbor image
    axs[row][4].imshow(neighbor_image_reshaped, cmap='gray')
    axs[row][4].set_title("Neighbor")
    axs[row][4].axis('off')

plt.tight_layout()
plt.show()
# Out:
# Biggest clique has 65 nodes

# %%
import torch
import matplotlib.pyplot as plt
import seaborn as sns

# Assume 'biggest_clique' is defined as the list of indices of nodes in the largest maximal clique,
# and 'unique_vectors' is a tensor of shape [n, 784] containing the vectors for all nodes.

# Extract the vectors corresponding to the biggest clique.
clique_indices = biggest_clique  # already a list of indices
clique_vectors = unique_vectors[clique_indices]  # shape: [num_points, 784]
num_points = clique_vectors.shape[0]
print(f"Biggest clique has {num_points} nodes.")

# Compute the pairwise Euclidean distance matrix.
# Using torch.cdist is efficient even for our small clique (65 nodes).
distance_matrix = torch.cdist(clique_vectors, clique_vectors, p=2)

print("Pairwise distance matrix (Euclidean distances):")
print(distance_matrix)

# Optional: Visualize the distance matrix as a heatmap.
plt.figure(figsize=(8, 6))
sns.heatmap(distance_matrix.cpu().numpy(), cmap='viridis', annot=False)
plt.title("Pairwise Euclidean Distance Matrix for Biggest Clique")
plt.xlabel("Node Index in Clique")
plt.ylabel("Node Index in Clique")
plt.show()
# Out:
# Biggest clique has 65 nodes.
# Pairwise distance matrix (Euclidean distances):
# tensor([[0.0000, 2.6458, 2.6458,  ..., 3.0000, 3.0000, 3.3166],
#         [2.6458, 0.0000, 2.0000,  ..., 2.4495, 2.8284, 2.0000],
#         [2.6458, 2.0000, 0.0000,  ..., 2.8284, 2.8284, 2.8284],
#         ...,
#         [3.0000, 2.4495, 2.8284,  ..., 0.0000, 3.4641, 3.1623],
#         [3.0000, 2.8284, 2.8284,  ..., 3.4641, 0.0000, 3.1623],
#         [3.3166, 2.0000, 2.8284,  ..., 3.1623, 3.1623, 0.0000]])

# %%
import random
import torch
import matplotlib.pyplot as plt

# --- Step 1: Pick two different maximal cliques and then one image from each.
if len(maximal_cliques) < 2:
    raise ValueError("Need at least 2 cliques to pick from.")

# Randomly sample 2 distinct cliques
clique_A, clique_B = random.sample(maximal_cliques, 2)

# Pick one random node from each clique
img1_idx = random.choice(clique_A)
img2_idx = random.choice(clique_B)

img1 = unique_vectors[img1_idx]
img2 = unique_vectors[img2_idx]

# --- Step 2: Interpolate between the two images with factors 0, 0.25, 0.5, 0.75, 1.0.
factors = [0.0, 0.25, 0.5, 0.75, 1.0]
interpolated_images = []
for t in factors:
    interp_img = (1 - t) * img1 + t * img2
    interpolated_images.append(interp_img.view(28, 28))

# --- Step 3: Define a helper to threshold images (convert to binary).
def threshold_image(img, threshold=0.5):
    # Given our images are (mostly) binary, we threshold them.
    return (img > threshold).float()

# --- Step 4: Calculate the percentage of pixel differences between consecutive images.
pixel_diffs = []
for i in range(len(interpolated_images) - 1):
    bin_img1 = threshold_image(interpolated_images[i])
    bin_img2 = threshold_image(interpolated_images[i+1])
    diff = (bin_img1 != bin_img2).sum().item()
    total_pixels = bin_img1.numel()
    percent_diff = (diff / total_pixels) * 100
    pixel_diffs.append(percent_diff)

# Also compute overall percentage difference between the two endpoints.
bin_img1_end = threshold_image(img1.view(28, 28))
bin_img2_end = threshold_image(img2.view(28, 28))
overall_diff = (bin_img1_end != bin_img2_end).sum().item()
overall_percent_diff = (overall_diff / bin_img1_end.numel()) * 100

# --- Step 5: Plot the interpolation images with titles showing percentage differences.
num_cols = len(interpolated_images)
fig, axs = plt.subplots(1, num_cols, figsize=(15, 4))

for i, img in enumerate(interpolated_images):
    axs[i].imshow(img, cmap='gray')
    axs[i].axis('off')
    if i == 0:
        title_str = "0% (Clique A)"
    elif i == num_cols - 1:
        title_str = f"100% (Clique B)\nOverall Δ: {overall_percent_diff:.1f}%"
    else:
        title_str = f"{int(factors[i]*100)}%\nΔ: {pixel_diffs[i-1]:.1f}%"
    axs[i].set_title(title_str)

plt.suptitle("Interpolation between images from two different cliques")
plt.show()

print(f"Overall, {overall_percent_diff:.1f}% of pixels differ between the two endpoint images.")
# Out:
# Overall, 4.7% of pixels differ between the two endpoint images.

# %%
# def greedy_minimal_clique_cover(maximal_cliques, universe):
#     """
#     Compute an approximate minimal clique cover using a greedy heuristic.

#     Args:
#         maximal_cliques (list of lists): Each sublist is a maximal clique (list of node IDs).
#         universe (set): Set of nodes (IDs) that must be covered.

#     Returns:
#         cover (list of lists): A list of cliques chosen to cover the universe.
#     """
#     cover = []
#     remaining = set(universe)  # Nodes that are not yet covered

#     # Keep selecting cliques until all nodes are covered
#     while remaining:
#         # Choose the clique that covers the largest number of remaining nodes.
#         best_clique = max(maximal_cliques, key=lambda clique: len(set(clique) & remaining))
#         cover.append(best_clique)
#         # Remove the nodes covered by the chosen clique from the remaining set.
#         remaining -= set(best_clique)

#     return cover

# # For example, suppose we want to cover all nodes in our main component.
# # Assuming G_main is your main component subgraph.
# universe = set(G_main.nodes())

# # Compute the greedy minimal clique cover.
# clique_cover = greedy_minimal_clique_cover(maximal_cliques, universe)

# print(f"Greedy minimal clique cover uses {len(clique_cover)} cliques to cover {len(universe)} nodes.")
# for i, clique in enumerate(clique_cover):
#     print(f"Clique {i}: covers {len(clique)} nodes")

# %%
# Precompute a mapping from node to the set of maximal clique indices it belongs to.
node_to_cliques = {}
for i, clique in enumerate(maximal_cliques):
    for node in clique:
        node_to_cliques.setdefault(node, set()).add(i)

# Count the number of bridge edges in G.
bridge_count = 0
for u, v in G.edges():
    if u in node_to_cliques and v in node_to_cliques and node_to_cliques[u].isdisjoint(node_to_cliques[v]):
        bridge_count += 1

print("Number of bridge edges:", bridge_count)
# Out:
# Number of bridge edges: 0

# %% [markdown]
# so to summarize what ive done i have 784d vectors of mnist 1s. i connected the graph based on each vector being a node and having an edge to each node within a certain euclidean distance of other nodes. then picked the biggest connected component of this graph. found the cliques which means collections of nodes that are all less than threshold distance to each other. when i have a bridge edge this means find an edge between 2 nodes that do not share a clique. 2 nodes only share an edge if they are within the threshold of each other. cliques are groups who are all connected meaning less than threshold distance to each other. so if 2 nodes have an edge they must be less than threshold distance and that in and of itself would create a clique of size 2

# %%
import matplotlib.pyplot as plt

# Compute membership counts for each node (i.e., number of maximal cliques each node belongs to)
membership_counts = [len(cliques) for cliques in node_to_cliques.values()]

# Plot the histogram
plt.figure(figsize=(10, 5))
# Create bins from 1 to max(membership_counts)+1 (so each integer value gets its own bin)
plt.hist(membership_counts, bins=range(1, max(membership_counts) + 2),
         color='skyblue', edgecolor='black', align='left')
plt.xlabel("Number of maximal cliques a node belongs to")
plt.ylabel("Number of nodes")
plt.title("Histogram of Maximal Clique Memberships per Node")
# plt.xticks(range(1, max(membership_counts) + 1))
plt.show()

# %%
# # prompt: find avg length of clique_to_cliques

# import numpy as np

# # Assuming clique_to_cliques is defined as in the provided code
# # Calculate the average length of the values in the clique_to_cliques dictionary
# avg_length = np.median([len(value) for value in clique_to_cliques.values()])
# print("Average length of clique_to_cliques:", avg_length)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-6b32afb8db1f> in <cell line: 0>()
#       5 # Assuming clique_to_cliques is defined as in the provided code
#       6 # Calculate the average length of the values in the clique_to_cliques dictionary
# ----> 7 avg_length = np.median([len(value) for value in clique_to_cliques.values()])
#       8 print("Average length of clique_to_cliques:", avg_length)
#
# NameError: name 'clique_to_cliques' is not defined

# %%
import random
import torch
import matplotlib.pyplot as plt

def find_pair_with_distance(vectors, target_distance, tolerance=0.2, max_tries=10000):
    """
    Randomly samples pairs of vectors until one is found whose Euclidean distance
    is within tolerance of target_distance.

    Args:
        vectors (torch.Tensor): Tensor of shape (n, 784).
        target_distance (float): The desired Euclidean distance.
        tolerance (float): Acceptable deviation.
        max_tries (int): Maximum number of random pairs to try.

    Returns:
        (i, j, d) tuple where i and j are indices and d is the distance,
        or (None, None, None) if no pair was found.
    """
    n = vectors.shape[0]
    for _ in range(max_tries):
        i = random.randint(0, n - 1)
        j = random.randint(0, n - 1)
        if i == j:
            continue
        d = torch.dist(vectors[i], vectors[j], p=2).item()
        if abs(d - target_distance) < tolerance:
            return i, j, d
    return None, None, None

# Define target distances you want to investigate.
target_distances = [3, 4, 5, 6, 7, 8, 9, 10]
factors = [0.0, 0.25, 0.5, 0.75, 1.0]

# List to store results: each item is (target, found_distance, list_of_interpolated_images)
results = []
for target in target_distances:
    i, j, d = find_pair_with_distance(unique_vectors, target, tolerance=0.2)
    if i is None:
        print(f"Could not find a pair for target distance {target}")
        continue
    interp_images = []
    for t in factors:
        # Linear interpolation between endpoints.
        interp = (1 - t) * unique_vectors[i] + t * unique_vectors[j]
        # If your vectors are binary (or thresholded), you might want to threshold them
        # e.g., interp = (interp > 0.5).float()
        interp_images.append(interp.view(28, 28).cpu().numpy())
    results.append((target, d, interp_images))

# Plot each row: one row per target distance.
num_rows = len(results)
num_cols = len(factors)
fig, axs = plt.subplots(num_rows, num_cols, figsize=(num_cols * 3, num_rows * 3))

for row_idx, (target, d, images) in enumerate(results):
    for col_idx, img in enumerate(images):
        axs[row_idx, col_idx].imshow(img, cmap='gray')
        # axs[row_idx, col_idx].axis('off')
        if col_idx == 0:
            axs[row_idx, col_idx].set_ylabel(f"Target: {target}\nDist: {d:.2f}", fontsize=10)
        axs[row_idx, col_idx].set_title(f"{int(factors[col_idx]*100)}%")
plt.tight_layout(rect=[0.1, 0, 1, 1])  # Leaves more space on the left
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import random

def plot_sampled_line_graphs(vectors, num_samples=10):
    """
    Randomly sample num_samples vectors from a set of 784-dimensional vectors,
    then plot each as a line graph where the x-axis represents the dimension index
    (0 to 783) and the y-axis is the pixel value (0 or 1).

    Args:
        vectors (torch.Tensor or np.array): Array of shape (n, 784) containing your vectors.
        num_samples (int): Number of random vectors to sample and plot.
    """
    # Convert to numpy array if needed.
    if hasattr(vectors, 'cpu'):
        X = vectors.cpu().numpy()
    else:
        X = np.array(vectors)

    n, dims = X.shape
    sample_indices = random.sample(range(n), min(num_samples, n))

    plt.figure(figsize=(20, 6))
    x_axis = np.arange(dims)  # dimensions 0 to 783

    for idx in sample_indices:
        # Each vector is binary (0 or 1); plot as a line graph.
        y_values = X[idx]
        plt.plot(x_axis, y_values, alpha=0.7, lw=1)

    plt.xlabel("Dimension Index")
    plt.ylabel("Pixel Value (0 or 1)")
    plt.title(f"Line Graphs for {num_samples} Randomly Sampled 784d Vectors")
    plt.ylim(-0.1, 1.1)
    plt.show()

# Example usage:
plot_sampled_line_graphs(unique_vectors, num_samples=10)

# %%
import matplotlib.pyplot as plt
import random
import numpy as np
import torch

def plot_digit_line_graphs_threshold(dataset, num_samples=10, threshold=0.5):
    """
    For each digit (0-9) in the dataset, randomly sample num_samples
    784-dimensional vectors (flattened images) and threshold them so that
    each pixel becomes 0 or 1. Then plot these as line graphs.

    Args:
      dataset: A PyTorch dataset (e.g., torchvision.datasets.MNIST) with
               attributes .data and .targets.
      num_samples (int): Number of images per digit to sample.
      threshold (float): Threshold value (e.g., 0.5) for binarizing the pixel values.
    """
    # Extract data and labels.
    # For MNIST, dataset.data is typically shape (n, 28, 28) and dataset.targets is shape (n,)
    data = dataset.data
    labels = dataset.targets

    # Convert data to float if needed.
    if not isinstance(data, torch.Tensor):
        data = torch.tensor(data)
    data = data.float()

    # If the data is in the 0-255 range, normalize to 0-1.
    if data.max() > 1:
        data = data / 255.0

    n = data.shape[0]
    # Flatten the images if needed: from (n, 28, 28) to (n, 784)
    if len(data.shape) > 2:
        data = data.view(n, -1)

    # Convert data and labels to NumPy arrays.
    data_np = data.cpu().numpy() if data.device.type == 'cuda' else data.numpy()
    labels = labels.cpu().numpy() if isinstance(labels, torch.Tensor) and labels.device.type == 'cuda' else np.array(labels)

    # Threshold the data to obtain binary images.
    binary_data = (data_np > threshold).astype(np.int32)

    # Create a subplot grid: 2 rows x 5 columns for digits 0 through 9.
    fig, axs = plt.subplots(2, 5, figsize=(20, 8))
    axs = axs.flatten()
    x_axis = np.arange(binary_data.shape[1])  # Dimensions: 0 to 783

    for digit in range(10):
        # Get indices for this digit.
        indices = np.where(labels == digit)[0]
        if len(indices) == 0:
            continue

        # Randomly sample indices for this digit.
        sample_indices = random.sample(list(indices), min(num_samples, len(indices)))
        ax = axs[digit]
        for idx in sample_indices:
            # Plot the binary vector as a line graph.
            ax.plot(x_axis, binary_data[idx], alpha=0.7)
        ax.set_title(f"Digit {digit}")
        ax.set_xlabel("Pixel Index")
        ax.set_ylabel("Binary Pixel Value")
        ax.set_ylim([-0.1, 1.1])

    plt.tight_layout()
    plt.show()

# Example usage:
# Assuming you have loaded the MNIST training set as mnist_train (e.g., using torchvision.datasets.MNIST)
plot_digit_line_graphs_threshold(mnist_train, num_samples=10, threshold=0.5)

# %%
import numpy as np
import torch
import matplotlib.pyplot as plt
from sklearn.neighbors import NearestNeighbors
from sklearn.manifold import TSNE
import networkx as nx

def visualize_threshold_graph(unique_vectors, distance_threshold):
    """
    Builds and visualizes a graph where each unique vector is a node and an edge is added
    between nodes if their Euclidean distance is <= distance_threshold.

    The visualization uses t-SNE to embed the nodes into 2D (to mimic a Kepler Mapper style).

    Args:
        unique_vectors (torch.Tensor or np.array): Array/tensor of shape (n, 784) containing unique images.
        distance_threshold (float): Maximum Euclidean distance for adding an edge between two nodes.
    """
    # Convert tensor to numpy array if necessary.
    if hasattr(unique_vectors, 'cpu'):
        X = unique_vectors.cpu().numpy()
    else:
        X = unique_vectors

    n = X.shape[0]
    print(f"Building graph for {n} nodes...")

    # Use NearestNeighbors to find all pairs within the distance threshold
    nbrs = NearestNeighbors(radius=distance_threshold, algorithm='ball_tree').fit(X)
    # indices[i] is an array of indices of neighbors for node i (including itself)
    distances, indices = nbrs.radius_neighbors(X)

    # Create an undirected graph and add nodes
    G = nx.Graph()
    G.add_nodes_from(range(n))

    # Add edges: For each node, add an edge to every neighbor with index > current node (to avoid duplicates)
    for i, neigh in enumerate(indices):
        for j in neigh:
            if i < j:
                G.add_edge(i, j)
    print(f"Graph built with {G.number_of_edges()} edges.")

    # Compute a 2D embedding for visualization using t-SNE.
    print("Computing 2D embedding with t-SNE...")
    X_reduced = TSNE(n_components=2, random_state=42).fit_transform(X)
    pos = {i: X_reduced[i] for i in range(n)}

    # Plot the graph
    plt.figure(figsize=(12, 10))
    nx.draw_networkx_nodes(G, pos, node_size=10, node_color='blue', alpha=0.6)
    nx.draw_networkx_edges(G, pos, alpha=0.3)
    plt.title(f"Graph of Unique Vectors (Edges if distance <= {distance_threshold})")
    plt.axis('off')
    plt.show()

    return G

G = visualize_threshold_graph(unique_vectors, distance_threshold=6)
# Out:
# Building graph for 6726 nodes...
# Graph built with 4681902 edges.
# Computing 2D embedding with t-SNE...

# %%
# Extract the main component (largest connected component) from G
main_component_nodes = max(nx.connected_components(G), key=len)
G_main = G.subgraph(main_component_nodes)

print(f"Main component has {G_main.number_of_nodes()} nodes and {G_main.number_of_edges()} edges.")

# --- 1. Cycle Basis (Cyclomatic Number) ---
# The cycle basis is a minimal set of cycles from which every cycle in the graph can be formed.
cycle_basis = nx.cycle_basis(G_main)
cyclomatic_number = len(cycle_basis)
print(f"Cyclomatic number (number of independent cycles) in the main component: {cyclomatic_number}")

# --- 2. Maximal Cliques ---
# A clique is a subset of nodes where every two nodes are connected.
# Finding all maximal cliques can be expensive for very large graphs.
print("Computing maximal cliques in the main component (this may take some time)...")
maximal_cliques = list(nx.find_cliques(G_main))
print(f"Number of maximal cliques in the main component: {len(maximal_cliques)}")

# Optionally, if you want to inspect the sizes of the largest cliques:
clique_sizes = [len(clique) for clique in maximal_cliques]
print(f"Max clique size: {max(clique_sizes)}; Average clique size: {np.mean(clique_sizes):.2f}")
# Out:
# Main component has 6631 nodes and 4681893 edges.
# Cyclomatic number (number of independent cycles) in the main component: 4675263
# Computing maximal cliques in the main component (this may take some time)...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-34-76ebf99a346b> in <cell line: 0>()
#      15 # Finding all maximal cliques can be expensive for very large graphs.
#      16 print("Computing maximal cliques in the main component (this may take some time)...")
# ---> 17 maximal_cliques = list(nx.find_cliques(G_main))
#      18 print(f"Number of maximal cliques in the main component: {len(maximal_cliques)}")
#      19
#
# /usr/local/lib/python3.11/dist-packages/networkx/algorithms/clique.py in find_cliques(G, nodes)
#     286                         subg = subg_q
#     287                         cand = cand_q
# --> 288                         u = max(subg, key=lambda u: len(cand & adj[u]))
#     289                         ext_u = cand - adj[u]
#     290             else:
#
# /usr/local/lib/python3.11/dist-packages/networkx/algorithms/clique.py in <lambda>(u)
#     286                         subg = subg_q
#     287                         cand = cand_q
# --> 288                         u = max(subg, key=lambda u: len(cand & adj[u]))
#     289                         ext_u = cand - adj[u]
#     290             else:
#
# KeyboardInterrupt:

# %%
# prompt: find total length of generator object nx.find_cliques(G_main)

import numpy as np

# Assuming maximal_cliques is defined as in the provided code
# Calculate the total length of the generator object
total_length = sum(1 for _ in nx.find_cliques(G_main))
print("Total length of generator object:", total_length)

# %%
# prompt: ouput sorted list of connected components by size of nodes in G

def sort_connected_components(graph):
    """
    Sorts connected components of a graph by the number of nodes in each component.

    Args:
        graph (nx.Graph): The input graph.

    Returns:
        list: A list of connected components, sorted in descending order by size.
              Each component is a list of node IDs.
    """
    connected_components = list(nx.connected_components(graph))
    sorted_components = sorted(connected_components, key=len, reverse=True)
    return sorted_components

# Example usage: Assuming 'G' is your graph
sorted_ccs = sort_connected_components(G)

# Print the sorted connected components and their sizes
for i, component in enumerate(sorted_ccs):
    print(f"Connected Component {i+1}: Size = {len(component)}")

# %%
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

def plot_pca_comparison(vectors, title, num_components=2):
    """
    Reduces the 784-dimensional data to num_components using PCA and plots a scatter plot.
    """
    pca = PCA(n_components=num_components)
    reduced = pca.fit_transform(vectors)
    plt.scatter(reduced[:, 0], reduced[:, 1], s=2, alpha=0.5)
    plt.title(title)
    plt.xlabel("PC1")
    plt.ylabel("PC2")

# Assume unique_vectors is a NumPy array of shape (n, 784) with values between 0 and 255.
# Plot for raw data (0–255):
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plot_pca_comparison(unique_vectors, "PCA of MNIST 1s (0–255)")

# Normalize the data to 0–1.
unique_vectors_norm = unique_vectors / 255.0
plt.subplot(1, 2, 2)
plot_pca_comparison(unique_vectors_norm, "PCA of MNIST 1s (0–1)")
plt.tight_layout()
plt.show()

# %%
# Import necessary libraries
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d.art3d import Poly3DCollection
import numpy as np

# Set up the figure and 3D axis
fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(111, projection='3d')

# Define half-length for x and y (prism width 1)
r = 0.5

# Define the vertices of the rectangular prism:
# x and y run from -0.5 to 0.5, and z runs from 0 (bottom) to 1 (top)
vertices = np.array([
    [-r, -r, 0],  # 0
    [ r, -r, 0],  # 1
    [ r,  r, 0],  # 2
    [-r,  r, 0],  # 3
    [-r, -r, 1],  # 4
    [ r, -r, 1],  # 5
    [ r,  r, 1],  # 6
    [-r,  r, 1]   # 7
])

# Define the six faces of the prism using the vertices
faces = [
    [vertices[0], vertices[1], vertices[2], vertices[3]],  # Bottom face (z = 0)
    [vertices[4], vertices[5], vertices[6], vertices[7]],  # Top face (z = 1)
    [vertices[0], vertices[1], vertices[5], vertices[4]],  # Side face
    [vertices[1], vertices[2], vertices[6], vertices[5]],  # Side face
    [vertices[2], vertices[3], vertices[7], vertices[6]],  # Side face
    [vertices[3], vertices[0], vertices[4], vertices[7]]   # Side face
]

# Create a 3D polygon collection for the prism faces
poly3d = Poly3DCollection(faces, facecolors='cyan', linewidths=1, edgecolors='r', alpha=0.3)
ax.add_collection3d(poly3d)

# Generate and plot random points inside the prism
num_points = 100
xs = np.random.uniform(-r, r, num_points)
ys = np.random.uniform(-r, r, num_points)
zs = np.random.uniform(0, 1, num_points)
ax.scatter(xs, ys, zs, color='black', s=20)

# Create an S-shaped plane inside the prism.
# We use parameters u and v: u ∈ [-0.5, 0.5] (along x) and v ∈ [0, 1] (along z).
# The y-coordinate is defined to be 0.5*sin(2*pi*v), creating the S shape.
u = np.linspace(-r, r, 30)
v = np.linspace(0, 1, 30)
U, V = np.meshgrid(u, v)

X = U
Y = 0.5 * np.sin(2 * np.pi * V)  # S-shaped displacement in y
Z = V

# Plot the S-shaped surface with a semi-transparent magenta color
ax.plot_surface(X, Y, Z, color='magenta', alpha=0.6)

# Set the axes limits to clearly show the prism, points, and S-shaped surface
ax.set_xlim([-1, 1])
ax.set_ylim([-1, 1])
ax.set_zlim([-0.2, 1.2])

# Label the axes
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

plt.show()
